# %% [markdown]
# <a href="https://colab.research.google.com/github/profclovesrocha/org_arq_comp/blob/main/Atv%2012.%20Ygor%20da%20Silva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import threading
import time

saldo = 1000
tranca = threading.Lock()

def atualizar_saldo(valor):
  global saldo
  with tranca:
    atual = saldo
    time.sleep(0.001) # Simulate some work
    saldo = atual + valor

t1 = threading.Thread(target=atualizar_saldo, args=(500,))
t2 = threading.Thread(target=atualizar_saldo, args=(-200,))

t1.start()
t2.start()

t1.join()
t2.join()

print(f"O saldo final é: {saldo}")
# Out:
# O saldo final é: 1300
