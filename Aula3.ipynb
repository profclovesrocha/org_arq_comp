# %% [markdown]
# <a href="https://colab.research.google.com/github/profclovesrocha/org_arq_comp/blob/main/Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# UNINASSAU PAULISTA
# DOCENTE: PROF. CLOVES ROCHA
# ESTUDANTE: PEDRO ALEXANDRE
# DICIPLINA: LOGICA DE PROGAMAÇAO

A = 10
B = 3
SOMA = (A + B)
Media = (A + B)/2
print('SOMA' , SOMA)
print('Media' , Media)
# Out:
# SOMA 13
# Media 6.5

# %%
n = 7
resto = n % 2
quad = n ** 2
print('resto da divisao por 2' , resto)
print('quadrado' , quad)
# Out:
# resto da divisao por 2 1
# quadrado 49
